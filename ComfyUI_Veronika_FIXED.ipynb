# %%
# 📁 Utwórz foldery na modele
# !mkdir -p models/checkpoints
# !mkdir -p models/ipadapter

# ✅ Pobierz Realistic Vision v5.1
# !wget -O models/checkpoints/Realistic_Vision_V5.1.safetensors \
https://huggingface.co/SG161222/Realistic_Vision_V5.1/resolve/main/Realistic_Vision_V5.1.safetensors

# ✅ Pobierz ReV Animated v1.5
# !wget -O models/checkpoints/ReV_Animated_v1.5.safetensors \
https://huggingface.co/SG161222/ReV_Animated_v1.5/resolve/main/ReV_Animated_v1.5.safetensors

# ✅ Pobierz IPAdapter SD1.5
# !wget -O models/ipadapter/ipadapter_sd15.bin \
https://huggingface.co/h94/IP-Adapter/resolve/main/models/ipadapter_sd15.bin

# %%
# ✅ Zainstaluj ngrok i uruchom ComfyUI z publicznym adresem
# !pip install flask-ngrok
from flask_ngrok import run_with_ngrok
import os

# Uruchom ComfyUI (upewnij się, że masz plik main.py w katalogu głównym)
os.system('python main.py')
